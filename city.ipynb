# %%
import osmnx as ox
import networkx as nx

# %%
monopoli = ox.graph_from_place('Monopoli, Italy', network_type='all')
fix, ax = ox.plot_graph(monopoli, node_size=0, edge_linewidth=0.5)

# %%
castellana = ox.graph_from_place('Castellana Grotte, Italy', network_type='all')
fix, ax = ox.plot_graph(castellana, node_size=0, edge_linewidth=0.5)

# %%
putignano = ox.graph_from_place('Putignano, Italy', network_type='all')
fix, ax = ox.plot_graph(putignano, node_size=0, edge_linewidth=0.5)

# %%
alberobello = ox.graph_from_place('Alberobello, Italy', network_type='all')
fix, ax = ox.plot_graph(alberobello, node_size=0, edge_linewidth=0.5)

# %%
conversano = ox.graph_from_place('Conversano, Italy', network_type='all')
fix, ax = ox.plot_graph(conversano, node_size=0, edge_linewidth=0.5)

# %%
noci = ox.graph_from_place('Noci, Italy', network_type='all')
fix, ax = ox.plot_graph(noci, node_size=0, edge_linewidth=0.5)

# %%
turi = ox.graph_from_place('Turi, Italy', network_type='all')
fix, ax = ox.plot_graph(turi, node_size=0, edge_linewidth=0.5)

# %%
adelfia = ox.graph_from_place('Adelfia, Italy', network_type='all')
fix, ax = ox.plot_graph(adelfia, node_size=0, edge_linewidth=0.5)

# %%
polignano = ox.graph_from_place('Polignano a Mare, Italy', network_type='all')
fix, ax = ox.plot_graph(polignano, node_size=0, edge_linewidth=0.5)

# %%
bari = ox.graph_from_place('Bari, Italy', network_type='all')
fix, ax = ox.plot_graph(bari, node_size=0, edge_linewidth=0.5)

# %%
bariD = ox.graph_from_place('Bari, Italy', network_type='drive')
fix, ax = ox.plot_graph(bariD, node_size=0, edge_linewidth=0.5)

# %%
madrid = ox.graph_from_place('Madrid, Spain', network_type='drive')
fix, ax = ox.plot_graph(madrid, node_size=0, edge_linewidth=0.5)

# %%
madrid = ox.graph_from_place('Madrid, Spain', network_type='all')
fix, ax = ox.plot_graph(madrid, node_size=0, edge_linewidth=0.5)

# %%
bcn = ox.graph_from_place('Barcelona, Spain', network_type='all')
fix, ax = ox.plot_graph(bcn, node_size=0, edge_linewidth=0.5)

# %%
jk = ox.graph_from_place('Jakarta, Indonesia', network_type='all')
fix, ax = ox.plot_graph(jk, node_size=0, edge_linewidth=0.5)

# %%
ny = ox.graph_from_place('New York, USA', network_type='all')
fix, ax = ox.plot_graph(ny, node_size=0, edge_linewidth=0.5)

# %%
nydrive = ox.graph_from_place('New York, New York, USA', network_type='drive')
fix, ax = ox.plot_graph(nydrive, node_size=0, edge_linewidth=0.5)

# %%
nym = ox.graph_from_place('Manhattan, New York, New York, USA', network_type='all')
fix, ax = ox.plot_graph(nym, node_size=0, edge_linewidth=0.5)

# %%
sv = ox.graph_from_place('Sevilla, Spain', network_type='all')
fix, ax = ox.plot_graph(sv, node_size=0, edge_linewidth=0.5)

# %%
ml = ox.graph_from_place('Malaga, Spain', network_type='all')
fix, ax = ox.plot_graph(ml, node_size=0, edge_linewidth=0.5)

# %%
nb = ox.graph_from_place('Neuburg an der Donau, Deutschland', network_type='all')
fix, ax = ox.plot_graph(nb, node_size=0, edge_linewidth=0.5)

# %%
palma = ox.graph_from_place('Palmanova, Italy', network_type='all')
fix, ax = ox.plot_graph(palma, node_size=0, edge_linewidth=0.5)

# %%
# oops, this gets the county of alameda rather than the city!
alameda1 = ox.graph_from_place("Alameda, California, USA", network_type="all")

# this gets the city of alameda
alameda2 = ox.graph_from_place(
    {
        "city": "Alameda",
        "county": "Alameda County",
        "state": "California",
        "country": "USA",
    }, network_type="all"
)

fix, ax = ox.plot_graph(alameda1, node_size=0, edge_linewidth=0.5)
fix, ax = ox.plot_graph(alameda2, node_size=0, edge_linewidth=0.5)
