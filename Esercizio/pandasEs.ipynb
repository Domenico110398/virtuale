# %%
import pandas as pd
import numpy as np

# Create a DataFrame with random values
np.random.seed(42)  # For reproducibility
df = pd.DataFrame(np.random.rand(10, 4), columns=['A', 'B', 'C', 'D'])

# Define a function to highlight specific columns with different colors
def highlight_columns(s):
    color_map = {
        'A': 'background-color: lightblue;', 
        'B': 'background-color: lightgreen;', 
        'C': 'background-color: lightcoral;', 
        'D': 'background-color: lightgoldenrodyellow;'
    }
    return [color_map.get(s.name, '')] * len(s)

# Apply styling
styled_df = df.style.apply(highlight_columns)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_ddfe3_row0_col0, #T_ddfe3_row1_col0, #T_ddfe3_row2_col0, #T_ddfe3_row3_col0, #T_ddfe3_row4_col0, #T_ddfe3_row5_col0, #T_ddfe3_row6_col0, #T_ddfe3_row7_col0, #T_ddfe3_row8_col0, #T_ddfe3_row9_col0 {
#   background-color: lightblue;
# }
# #T_ddfe3_row0_col1, #T_ddfe3_row1_col1, #T_ddfe3_row2_col1, #T_ddfe3_row3_col1, #T_ddfe3_row4_col1, #T_ddfe3_row5_col1, #T_ddfe3_row6_col1, #T_ddfe3_row7_col1, #T_ddfe3_row8_col1, #T_ddfe3_row9_col1 {
#   background-color: lightgreen;
# }
# #T_ddfe3_row0_col2, #T_ddfe3_row1_col2, #T_ddfe3_row2_col2, #T_ddfe3_row3_col2, #T_ddfe3_row4_col2, #T_ddfe3_row5_col2, #T_ddfe3_row6_col2, #T_ddfe3_row7_col2, #T_ddfe3_row8_col2, #T_ddfe3_row9_col2 {
#   background-color: lightcoral;
# }
# #T_ddfe3_row0_col3, #T_ddfe3_row1_col3, #T_ddfe3_row2_col3, #T_ddfe3_row3_col3, #T_ddfe3_row4_col3, #T_ddfe3_row5_col3, #T_ddfe3_row6_col3, #T_ddfe3_row7_col3, #T_ddfe3_row8_col3, #T_ddfe3_row9_col3 {
#   background-color: lightgoldenrodyellow;
# }
# </style>
# <table id="T_ddfe3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddfe3_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ddfe3_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_ddfe3_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_ddfe3_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddfe3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ddfe3_row0_col0" class="data row0 col0" >0.374540</td>
#       <td id="T_ddfe3_row0_col1" class="data row0 col1" >0.950714</td>
#       <td id="T_ddfe3_row0_col2" class="data row0 col2" >0.731994</td>
#       <td id="T_ddfe3_row0_col3" class="data row0 col3" >0.598658</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ddfe3_row1_col0" class="data row1 col0" >0.156019</td>
#       <td id="T_ddfe3_row1_col1" class="data row1 col1" >0.155995</td>
#       <td id="T_ddfe3_row1_col2" class="data row1 col2" >0.058084</td>
#       <td id="T_ddfe3_row1_col3" class="data row1 col3" >0.866176</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ddfe3_row2_col0" class="data row2 col0" >0.601115</td>
#       <td id="T_ddfe3_row2_col1" class="data row2 col1" >0.708073</td>
#       <td id="T_ddfe3_row2_col2" class="data row2 col2" >0.020584</td>
#       <td id="T_ddfe3_row2_col3" class="data row2 col3" >0.969910</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ddfe3_row3_col0" class="data row3 col0" >0.832443</td>
#       <td id="T_ddfe3_row3_col1" class="data row3 col1" >0.212339</td>
#       <td id="T_ddfe3_row3_col2" class="data row3 col2" >0.181825</td>
#       <td id="T_ddfe3_row3_col3" class="data row3 col3" >0.183405</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ddfe3_row4_col0" class="data row4 col0" >0.304242</td>
#       <td id="T_ddfe3_row4_col1" class="data row4 col1" >0.524756</td>
#       <td id="T_ddfe3_row4_col2" class="data row4 col2" >0.431945</td>
#       <td id="T_ddfe3_row4_col3" class="data row4 col3" >0.291229</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ddfe3_row5_col0" class="data row5 col0" >0.611853</td>
#       <td id="T_ddfe3_row5_col1" class="data row5 col1" >0.139494</td>
#       <td id="T_ddfe3_row5_col2" class="data row5 col2" >0.292145</td>
#       <td id="T_ddfe3_row5_col3" class="data row5 col3" >0.366362</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ddfe3_row6_col0" class="data row6 col0" >0.456070</td>
#       <td id="T_ddfe3_row6_col1" class="data row6 col1" >0.785176</td>
#       <td id="T_ddfe3_row6_col2" class="data row6 col2" >0.199674</td>
#       <td id="T_ddfe3_row6_col3" class="data row6 col3" >0.514234</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ddfe3_row7_col0" class="data row7 col0" >0.592415</td>
#       <td id="T_ddfe3_row7_col1" class="data row7 col1" >0.046450</td>
#       <td id="T_ddfe3_row7_col2" class="data row7 col2" >0.607545</td>
#       <td id="T_ddfe3_row7_col3" class="data row7 col3" >0.170524</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ddfe3_row8_col0" class="data row8 col0" >0.065052</td>
#       <td id="T_ddfe3_row8_col1" class="data row8 col1" >0.948886</td>
#       <td id="T_ddfe3_row8_col2" class="data row8 col2" >0.965632</td>
#       <td id="T_ddfe3_row8_col3" class="data row8 col3" >0.808397</td>
#     </tr>
#     <tr>
#       <th id="T_ddfe3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ddfe3_row9_col0" class="data row9 col0" >0.304614</td>
#       <td id="T_ddfe3_row9_col1" class="data row9 col1" >0.097672</td>
#       <td id="T_ddfe3_row9_col2" class="data row9 col2" >0.684233</td>
#       <td id="T_ddfe3_row9_col3" class="data row9 col3" >0.440152</td>
#     </tr>
#   </tbody>
# </table>
