# %% [markdown]
# # Questo è un titolo
# ## Questo è un sottone
# Questo è del normale testo mentre questo <b>è più cicciotto</b>
#
# Questa di seguito è una lista puntata:
# - primo elemento lista
# - secondo elemento lista

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import the dataset
# pippo = pd.read_csv('https://raw.githubusercontent.com/vincenzorrei/EDU-Datasets/refs/heads/main/Advertising.csv',
#                           usecols=[1,2,3,4])

# %%
pippo = pd.read_csv('https://raw.githubusercontent.com/vincenzorrei/EDU-Datasets/refs/heads/main/Credit.csv')

# %%
pippo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  400 non-null    int64
#  1   Income      400 non-null    float64
#  2   Limit       400 non-null    int64
#  3   Rating      400 non-null    int64
#  4   Cards       400 non-null    int64
#  5   Age         400 non-null    int64
#  6   Education   400 non-null    int64
#  7   Gender      400 non-null    object
#  8   Student     400 non-null    object
#  9   Married     400 non-null    object
#  10  Ethnicity   400 non-null    object
#  11  Balance     400 non-null    int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 37.6+ KB

# %%
print(pippo.dtypes)
# Out:
# Unnamed: 0      int64
# Income        float64
# Limit           int64
# Rating          int64
# Cards           int64
# Age             int64
# Education       int64
# Gender         object
# Student        object
# Married        object
# Ethnicity      object
# Balance         int64
# dtype: object

# %%
print(pippo.columns)
# Out:
# Index(['Unnamed: 0', 'Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education',
#        'Gender', 'Student', 'Married', 'Ethnicity', 'Balance'],
#       dtype='object')

# %%
print(pippo.columns[1:3])
# Out:
# Index(['Income', 'Limit'], dtype='object')

# %%
print(pippo.shape)
# Out:
# (400, 12)

# %%
print(type(pippo))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
pippo.head(3)
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580

# %%
pippo.tail(2)
# Out:
#      Unnamed: 0  Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 398         399  37.728   2525     192      1   44         13    Male      No
# 399         400  18.701   5524     415      5   64          7  Female      No
#
#     Married  Ethnicity  Balance
# 398     Yes  Caucasian        0
# 399      No      Asian      966

# %%
pippo.iloc[25:30]
# Out:
#     Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 25          26   14.090   4323     326      5   25         16  Female      No
# 26          27   42.471   3625     289      6   44         12  Female     Yes
# 27          28   32.793   4534     333      2   44         16    Male      No
# 28          29  186.634  13414     949      2   41         14  Female      No
# 29          30   26.813   5611     411      4   55         16  Female      No
#
#    Married         Ethnicity  Balance
# 25     Yes  African American      671
# 26      No         Caucasian      654
# 27      No  African American      467
# 28     Yes  African American     1809
# 29      No         Caucasian      915

# %%
pippo.iloc[20:25][['Income', 'Rating']]
# Out:
#     Income  Rating
# 20  17.700     235
# 21  37.348     458
# 22  20.103     213
# 23  64.027     398
# 24  10.742     156

# %%
pippo.iloc[20:25, 1:3]
# Out:
#     Income  Limit
# 20  17.700   2860
# 21  37.348   6378
# 22  20.103   2631
# 23  64.027   5179
# 24  10.742   1757

# %%
pippo.describe()
# Out:
#        Unnamed: 0      Income         Limit      Rating       Cards  \
# count  400.000000  400.000000    400.000000  400.000000  400.000000
# mean   200.500000   45.218885   4735.600000  354.940000    2.957500
# std    115.614301   35.244273   2308.198848  154.724143    1.371275
# min      1.000000   10.354000    855.000000   93.000000    1.000000
# 25%    100.750000   21.007250   3088.000000  247.250000    2.000000
# 50%    200.500000   33.115500   4622.500000  344.000000    3.000000
# 75%    300.250000   57.470750   5872.750000  437.250000    4.000000
# max    400.000000  186.634000  13913.000000  982.000000    9.000000
#
#               Age   Education      Balance
# count  400.000000  400.000000   400.000000
# mean    55.667500   13.450000   520.015000
# std     17.249807    3.125207   459.758877
# min     23.000000    5.000000     0.000000
# 25%     41.750000   11.000000    68.750000
# 50%     56.000000   14.000000   459.500000
# 75%     70.000000   16.000000   863.000000
# ...

# %%
pippo.describe().T
# Out:
#             count         mean          std      min         25%        50%  \
# Unnamed: 0  400.0   200.500000   115.614301    1.000   100.75000   200.5000
# Income      400.0    45.218885    35.244273   10.354    21.00725    33.1155
# Limit       400.0  4735.600000  2308.198848  855.000  3088.00000  4622.5000
# Rating      400.0   354.940000   154.724143   93.000   247.25000   344.0000
# Cards       400.0     2.957500     1.371275    1.000     2.00000     3.0000
# Age         400.0    55.667500    17.249807   23.000    41.75000    56.0000
# Education   400.0    13.450000     3.125207    5.000    11.00000    14.0000
# Balance     400.0   520.015000   459.758877    0.000    68.75000   459.5000
#
#                    75%        max
# Unnamed: 0   300.25000    400.000
# Income        57.47075    186.634
# Limit       5872.75000  13913.000
# Rating       437.25000    982.000
# Cards          4.00000      9.000
# Age           70.00000     98.000
# Education     16.00000     20.000
# ...

# %%
pippo.describe(include='all')
# Out:
#         Unnamed: 0      Income         Limit      Rating       Cards  \
# count   400.000000  400.000000    400.000000  400.000000  400.000000
# unique         NaN         NaN           NaN         NaN         NaN
# top            NaN         NaN           NaN         NaN         NaN
# freq           NaN         NaN           NaN         NaN         NaN
# mean    200.500000   45.218885   4735.600000  354.940000    2.957500
# std     115.614301   35.244273   2308.198848  154.724143    1.371275
# min       1.000000   10.354000    855.000000   93.000000    1.000000
# 25%     100.750000   21.007250   3088.000000  247.250000    2.000000
# 50%     200.500000   33.115500   4622.500000  344.000000    3.000000
# 75%     300.250000   57.470750   5872.750000  437.250000    4.000000
# max     400.000000  186.634000  13913.000000  982.000000    9.000000
#
#                Age   Education  Gender Student Married  Ethnicity      Balance
# ...

# %%
print(pippo['Student'].value_counts()) # mostra i valori unici della colonna selezionata
# Out:
# Student
# No     360
# Yes     40
# Name: count, dtype: int64

# %%
print(pippo['Ethnicity'].value_counts())
# Out:
# Ethnicity
# Caucasian           199
# Asian               102
# African American     99
# Name: count, dtype: int64

# %%
print(pippo['Married'].value_counts())
# Out:
# Married
# Yes    245
# No     155
# Name: count, dtype: int64

# %%
pippo['Balance']
# Out:
# 0      333
# 1      903
# 2      580
# 3      964
# 4      331
#       ...
# 395    560
# 396    480
# 397    138
# 398      0
# 399    966
# Name: Balance, Length: 400, dtype: int64

# %%
# Partendo da un colonna PANDAS
pippo['Balance'].hist(bins=20,
                      figsize=(10,5),
                      color='rebeccapurple',
                      edgecolor='white',
                      linewidth=2,
                    #   xlabelsize=20,
                    #   xrot=45,
                    #   ylabelsize=2
                 # linewidth=3,
                 # legend=True,
                )
# plt.title('Distribution of Balance', fontsize=20)
# plt.xlabel('Balance', fontsize=15, loc='left')
# plt.ylabel('Frequency', fontsize=15, loc='top')
# plt.grid(axis='y', linestyle='--', alpha=0.7, color='black')
# plt.xlim(left=-500,right= 3000)
# plt.xticks(fontsize=10)
# Out:
# <Axes: >

# %%
pippo['Balance'].hist()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
plt.hist(x=pippo['Balance'],
         bins=20,
         color='rebeccapurple',
         edgecolor='white',
         linewidth=2,)
plt.grid()

# %%
plt.figure(figsize=(10,5))
plt.plot(pippo['Income'], pippo['Balance'],'P', markeredgecolor = 'dodgerblue', color='w', alpha=1) # scatterplot
plt.grid()

# %%
plt.plot(pippo['Income'], pippo['Balance'],'o', color='rebeccapurple', alpha=0.5)
plt.title('Income vs Balance', fontsize=20)
plt.xlabel('Income', fontsize=15, loc='left')
plt.ylabel('Balance', fontsize=15, loc='top')
plt.grid(axis='y', linestyle='--', alpha=0.7, color='black')
plt.xticks(fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(['Balance'], loc='upper right', fontsize=10)
plt.show()

# %%
x, y = pippo['Income'], pippo['Balance']
plt.hist2d(x, y, bins=(50, 50), cmap=plt.cm.Reds)

# Add a basic title
plt.title("A 2D histogram")

# Show the graph
plt.show()

# %%
print(pippo.duplicated().sum())
# Out:
# 0

# %%
import pandas as pd
pippo = pd.read_csv('https://raw.githubusercontent.com/vincenzorrei/EDU-Datasets/refs/heads/main/Advertising.csv')
pippo
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
pippo[['TV', 'sales']].plot(kind='scatter', x='TV', y='sales')
# Out:
# <Axes: xlabel='TV', ylabel='sales'>

# %%
pippo.to_csv('pippo_lindo_e_pinto.csv', index=False)

# %%
df = pippo

# %%
plt.hist(np.random.normal(scale=1.2, size=20000),  edgecolor='white',
         color='rebeccapurple',
         linewidth=1,
         bins = 20)
# Out:
# (array([   7.,   19.,   67.,  154.,  391.,  762., 1372., 2054., 2702.,
#         3036., 2875., 2547., 1770., 1105.,  661.,  285.,  133.,   40.,
#           14.,    6.]),
#  array([-4.52138969, -4.06217542, -3.60296116, -3.14374689, -2.68453263,
#         -2.22531836, -1.7661041 , -1.30688984, -0.84767557, -0.38846131,
#          0.07075296,  0.52996722,  0.98918148,  1.44839575,  1.90761001,
#          2.36682428,  2.82603854,  3.28525281,  3.74446707,  4.20368133,
#          4.6628956 ]),
#  <BarContainer object of 20 artists>)

# %%
# Generare dati artificiali
np.random.seed(42)
x = np.linspace(0, 10, 100)  # 100 punti equidistanti tra 0 e 10
y = np.sin(x) + np.random.normal(scale=0.1, size=len(x))  # Seno con rumore

# Creare un nuovo grafico a linee
plt.figure(figsize=(10, 5))

# Lineplot Lime
plt.plot(x, y, marker="o", linestyle="-", color="lime", alpha=0.7, label="Curva lime")

# Creazionhe di una nuov y per un'altra serie
y2 = np.sin(x-1) + np.random.normal(scale=0.1, size=len(x))  # Seno con rumore

# Lineplot SALMONE
plt.plot(x, y2, marker="o", linestyle="-", color="darksalmon", alpha=0.7, label="Curva salmone")

# Riempimento
plt.fill_between(x, y, y2, color="lightblue", alpha=0.7)

# Aggiungere una linea orizzontale BLU
plt.plot([2, 8], [-0.5, 0.5], marker=">", linestyle="-", color="dodgerblue", alpha=0.7, label="Linea blu")

# Triangolo singolo 
plt.scatter([5], [0.5], marker="v", linestyle="-", color="darkred", alpha=0.7, label="Triangolo rosso") # usiamo scatter per far si che sia semplicemnte un punto

# Aggiungere etichette e titolo
plt.xlabel("Questa e la ylabel")
plt.ylabel("Questa e la ylabel")
plt.title("Qui va il titolo")
plt.legend() # prende in automatico le label che abbiamo selezionato ad ogni plot
plt.grid(True, color="gray", alpha=0.5)

# Mostrare il grafico
plt.show()

# %%
coord_x = np.linspace(0, 10, 100)  # 100 punti equidistanti tra 0 e 10
coord_y = np.sin(x) + np.random.normal(scale=0.1, size=len(x))  # Seno con rumore

dimensione_z = np.random.normal(scale=0.1, size=len(x))  # Coseno con rumore
gruppo_k = np.random.randint(1, 7, size=len(x))  # Valori casuali per le dimensioni dei punti

plt.scatter(coord_x, coord_y,
            s=dimensione_z*3000,
            c=gruppo_k, cmap='viridis')
# Out:
# c:\Users\dilau\Desktop\Develope-ghit\virtuale\.venv\Lib\site-packages\matplotlib\collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

# Creazione dati artificiali
N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii


# Impostazioni grafico
c = np.sqrt(area)
r = np.sqrt(x ** 2 + y ** 2)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
theta = np.arange(0, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

plt.show()

# %%
# Generare dati artificiali distribuiti normalmente
# np.random.seed(42)  # Imposta il seed per riproducibilità dei risultati
data = np.random.normal(
    loc=0,    # Media della distribuzione (centro dei dati)
    scale=1,  # Deviazione standard (dispersione dei dati)
    size=1000 # Numero di campioni da generare
)

# Calcolare i quartili
q1, q2, q3 = np.percentile(
    data,       # Array dei dati
    [25, 50, 75] # Percentili da calcolare (25% = Q1, 50% = mediana, 75% = Q3)
)

# Creare l'istogramma
plt.figure(
    figsize=(10, 5) # Dimensioni della figura (larghezza, altezza in pollici)
)
plt.hist(
    data, 
    bins=70,          # Numero di contenitori/barre nell'istogramma (può essere anche una lista o una stringa per algoritmi automatici)
    color="skyblue",  # Colore di riempimento delle barre
    edgecolor="white", # Colore dei bordi delle barre
    alpha=0.7,        # Trasparenza (0 = trasparente, 1 = opaco)
    density=False,    # Se True, normalizza l'area a 1 (probabilità invece che conteggi)
    # cumulative=True, # Mostra la distribuzione cumulativa
    # label='Dati',    # Etichetta per la legenda
    # orientation='horizontal', # Orientamento dell'istogramma
    # histtype='step', # Tipo di istogramma ('bar', 'barstacked', 'step', 'stepfilled')
    # log=True,        # Scala logaritmica sull'asse y
    # stacked=True,    # Sovrappone più istogrammi
    # align='mid',     # Allineamento barre ('left', 'mid', 'right')
    # range=(-3, 3)    # Intervallo valori da considerare
)

# Aggiungere linee per i quartili
plt.axvline(q1, color="red", linestyle="dashed", linewidth=2, label="1° Quartile (Q1)")
plt.axvline(q2, color="green", linestyle="dashed", linewidth=2, label="Mediana (Q2)")
plt.axvline(q3, color="purple", linestyle="dashed", linewidth=2, label="3° Quartile (Q3)")

# Aggiungere etichette e titolo
plt.xlabel("Valore")          # Etichetta asse X
plt.ylabel("Frequenza")       # Etichetta asse Y
plt.title("Istogramma con Quartili") # Titolo del grafico
plt.legend(                   # Mostra la legenda
    loc='best',               # Posizione automatica della legenda
    frameon=True,             # Mostra lo sfondo
    shadow=True               # Aggiungi ombra
)
plt.grid(
    axis="y",       # Mostra griglia solo per l'asse Y ('both', 'x', 'y')
    linestyle="--", # Stile delle linee della griglia
    alpha=0.7       # Trasparenza della griglia
)

# Personalizzazione aggiuntiva
plt.xlim(-4, 4)      # Limiti dell'asse X
plt.ylim(0, 50)   # Limiti dell'asse Y
plt.tight_layout()   # Migliora il layout automaticamente

# Mostrare il grafico
plt.show()

# %%
import random
import os
extracted_indexes = [i for i in range(0, len(data))]

# %%
num_bins = 70
bin_edges = np.linspace(-4, 4, num_bins + 1)

# %%
def add_observation(i):
    # Estrai un elemento da extracted_indexes
    index = random.choice(extracted_indexes)
    extracted_indexes.remove(index)
    new_data = data[extracted_indexes]
    q1, q2, q3 = np.percentile(new_data, [25, 50, 75])

    plt.figure(figsize=(10, 5)) 
    
    plt.hist(new_data, bins=bin_edges, color="skyblue", edgecolor="white", alpha=0.7, density=False)
    
    plt.axvline(q1, color="dodgerblue", linestyle="dashed", linewidth=2, label="1° Quartile (Q1)")
    plt.axvline(q2, color="darkred", linestyle="dashed", linewidth=2, label="Mediana (Q2)")
    plt.axvline(q3, color="gold", linestyle="dashed", linewidth=2, label="3° Quartile (Q3)")
    
    plt.xlabel("Valore")          # Etichetta asse X
    plt.ylabel("Frequenza")       # Etichetta asse Y
    plt.title("Istogramma con Quartili") # Titolo del grafico
    plt.legend(loc='best', frameon=True, shadow=True )
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.xlim(-4, 4)  # Limiti dell'asse Y
    plt.ylim(0, 50)   # Limiti dell'asse Y
    plt.tight_layout()
    frame_path = os.path.join('images', f"frame_{i:03d}.png")
    plt.savefig(frame_path, dpi=100)
    plt.close()

# %%
# for i in range(len(data)):
    # add_observation(i)

# %%
import cv2
import os

def create_video(output_video="video.mp4", fps=10):
    frame_files = sorted(os.listdir('images'), reverse=True)
    #frame_files = [f for f in frame_files if f.endswith('.png')]
      # Ordina i frame
    frame_path = os.path.join('images', frame_files[0])
    
    # Carichiamo il primo frame per ottenere dimensioni
    frame = cv2.imread(frame_path)
    height, width, _ = frame.shape
    
    # Impostiamo il video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec per MP4
    out = cv2.VideoWriter(output_video, fourcc, fps, (width, height))

    for file in frame_files:
        frame_path = os.path.join('images', file)
        frame = cv2.imread(frame_path)
        out.write(frame)

    out.release()
    print(f"Video salvato come {output_video}")

# Creiamo il video
# create_video()

# %%
pippo = pd.read_csv('https://raw.githubusercontent.com/vincenzorrei/EDU-Datasets/refs/heads/main/Credit.csv')

# %%
pippo.describe()
# Out:
#        Unnamed: 0      Income         Limit      Rating       Cards  \
# count  400.000000  400.000000    400.000000  400.000000  400.000000
# mean   200.500000   45.218885   4735.600000  354.940000    2.957500
# std    115.614301   35.244273   2308.198848  154.724143    1.371275
# min      1.000000   10.354000    855.000000   93.000000    1.000000
# 25%    100.750000   21.007250   3088.000000  247.250000    2.000000
# 50%    200.500000   33.115500   4622.500000  344.000000    3.000000
# 75%    300.250000   57.470750   5872.750000  437.250000    4.000000
# max    400.000000  186.634000  13913.000000  982.000000    9.000000
#
#               Age   Education      Balance
# count  400.000000  400.000000   400.000000
# mean    55.667500   13.450000   520.015000
# std     17.249807    3.125207   459.758877
# min     23.000000    5.000000     0.000000
# 25%     41.750000   11.000000    68.750000
# 50%     56.000000   14.000000   459.500000
# 75%     70.000000   16.000000   863.000000
# ...

# %%
col_name = 'Income'
bins = 80
data = pippo[col_name]
q1, q2, q3 = np.percentile(data, [25, 50, 75])

# Creare l'istogramma
plt.figure(figsize=(10, 5))
plt.hist(data,
         bins=bins,
         color="skyblue",
         edgecolor="white", alpha=0.7)

# Aggiungere linee per i quartili
plt.axvline(q1, color="red", linestyle="dashed", linewidth=1, label="1° Quartile (Q1)")
plt.axvline(q2, color="green", linestyle="dashed", linewidth=1, label="Mediana (Q2)")
plt.axvline(q3, color="purple", linestyle="dashed", linewidth=1, label="3° Quartile (Q3)")

# Aggiungere etichette e titolo
plt.xlabel(col_name)
plt.ylabel("Frequenza")
plt.title("Istogramma con Quartili")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Mostrare il grafico
plt.show()

# %%
max_val = pippo['Income'].max()
min_val = pippo['Income'].min()
range_val = max_val - min_val

bin_size = range_val / bins

print(f"Min value: {min_val}")
print(f"Bin size: {bin_size}")
print(f"End first bin: {min_val + bin_size}")
# Out:
# Min value: 10.354
# Bin size: 2.2034999999999996
# End first bin: 12.5575

# %%
is_poor = pippo['Balance'] < 500
print(is_poor)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 395    False
# 396     True
# 397     True
# 398     True
# 399    False
# Name: Balance, Length: 400, dtype: bool

# %%
make_money = pippo['Income'] > 100
print(make_money)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: Income, Length: 400, dtype: bool

# %%
is_young = pippo['Age'] <= pippo['Age'].median()

# %%
pippo[make_money & is_poor & ~ is_young]
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 108         109  107.986   6033     449      4   64         14    Male
# 121         122  148.080   8157     599      2   83         13    Male
# 278         279  128.040   6982     518      2   78         11  Female
#
#     Student Married  Ethnicity  Balance
# 108      No     Yes  Caucasian      227
# 121      No     Yes  Caucasian      454
# 278      No     Yes  Caucasian      250

# %%
col_val = 'Income'
data = pippo[col_val]
plt.figure(figsize=(5, 10))
plt.violinplot(data,
    showmedians=True,
    # showmeans=True,
    quantiles=[0.25,0.5, 0.75])
interqueritle_distance = np.percentile(data, 75) - np.percentile(data, 25)


outlier_limit_up = np.percentile(data, 75) + interqueritle_distance * 1.5
outlier_limit_down = max(np.percentile(data, 25) - interqueritle_distance * 1.5, min(data))


plt.plot([0.8, 1.2], [outlier_limit_up, outlier_limit_up], color='darkred', linestyle='dashed', linewidth=1)
plt.plot([0.8, 1.2], [outlier_limit_down, outlier_limit_down], color='darkred', linestyle='dashed', linewidth=1)

plt.title(f'Violin plot: {col_val}')
plt.xlabel(col_val)
plt.ylabel('Valore')
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
col_val_x = 'Income'
col_val_y = 'Balance'
col_dimension = 'Education'
data_x = pippo[col_val_x]
data_y = pippo[col_val_y]
colors = pippo['Student'].map({'Yes': 'darkred', 'No': 'dodgerblue'})
dimension = pippo[col_dimension] * 10
plt.figure(figsize=(15, 8))
plt.scatter(data_x, data_y,
            c=colors,
            s=dimension,
            alpha=0.5,
            label="No Student"
    )
plt.title(f'Scatter plot: {col_val}')
plt.xlabel(col_val_x)
plt.ylabel(col_val_y)
plt.legend(['Student'])
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
# Chied a Claude 3.5 di ottimizzare questo codice
col_val_x = 'Income'
col_val_y = 'Balance'
col_dimension = 'Education'

married = pippo[pippo['Married'] == 'Yes']


plt.figure(figsize=(15, 8))
# Married
data_x = married[col_val_x]
data_y = married[col_val_y]
colors = married['Student'].map({'Yes': 'darkred', 'No': 'dodgerblue'})
dimension = married[col_dimension] * 10

plt.scatter(data_x, data_y,
            c=colors,
            s=dimension,
            alpha=0.5,
            label="Married",
            marker = '>'
    )

# Married
unmarried = pippo[pippo['Married'] == 'No']
data_x = unmarried[col_val_x]
data_y = unmarried[col_val_y]
colors = unmarried['Student'].map({'Yes': 'darkred', 'No': 'dodgerblue'})
dimension = unmarried[col_dimension] * 10

plt.scatter(data_x, data_y,
            c=colors,
            s=dimension,
            alpha=0.5,
            label="Unmarried",
            marker = 'o'
    )


plt.title(f'Scatter plot: {col_val}')
plt.xlabel(col_val_x)
plt.ylabel(col_val_y)
plt.legend()
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
pippo
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# ..          ...      ...    ...     ...    ...  ...        ...     ...
# 395         396   12.096   4100     307      3   32         13    Male
# 396         397   13.364   3838     296      5   65         17    Male
# 397         398   57.872   4171     321      5   67         12  Female
# 398         399   37.728   2525     192      1   44         13    Male
# 399         400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# 0        No     Yes         Caucasian      333
# ...

# %%
# print(pippo.drop('Unnamed: 0', axis=1, inplace=True))

# %%
pippo = pippo.drop('Unnamed: 0', axis=1)

# %%
pippo
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0     14.891   3606     283      2   34         11    Male      No     Yes
# 1    106.025   6645     483      3   82         15  Female     Yes     Yes
# 2    104.593   7075     514      4   71         11    Male      No      No
# 3    148.924   9504     681      3   36         11  Female      No      No
# 4     55.882   4897     357      2   68         16    Male      No     Yes
# ..       ...    ...     ...    ...  ...        ...     ...     ...     ...
# 395   12.096   4100     307      3   32         13    Male      No     Yes
# 396   13.364   3838     296      5   65         17    Male      No      No
# 397   57.872   4171     321      5   67         12  Female      No     Yes
# 398   37.728   2525     192      1   44         13    Male      No     Yes
# 399   18.701   5524     415      5   64          7  Female      No      No
#
#             Ethnicity  Balance
# 0           Caucasian      333
# ...

# %%
pippo.select_dtypes(include=["number"])
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Balance
# 0     14.891   3606     283      2   34         11      333
# 1    106.025   6645     483      3   82         15      903
# 2    104.593   7075     514      4   71         11      580
# 3    148.924   9504     681      3   36         11      964
# 4     55.882   4897     357      2   68         16      331
# ..       ...    ...     ...    ...  ...        ...      ...
# 395   12.096   4100     307      3   32         13      560
# 396   13.364   3838     296      5   65         17      480
# 397   57.872   4171     321      5   67         12      138
# 398   37.728   2525     192      1   44         13        0
# 399   18.701   5524     415      5   64          7      966
#
# [400 rows x 7 columns]

# %%
corr_matrix = pippo.select_dtypes(include=["number"]).corr()
corr_matrix
# Out:
#              Income     Limit    Rating     Cards       Age  Education  \
# Income     1.000000  0.792088  0.791378 -0.018273  0.175338  -0.027692
# Limit      0.792088  1.000000  0.996880  0.010231  0.100888  -0.023549
# Rating     0.791378  0.996880  1.000000  0.053239  0.103165  -0.030136
# Cards     -0.018273  0.010231  0.053239  1.000000  0.042948  -0.051084
# Age        0.175338  0.100888  0.103165  0.042948  1.000000   0.003619
# Education -0.027692 -0.023549 -0.030136 -0.051084  0.003619   1.000000
# Balance    0.463656  0.861697  0.863625  0.086456  0.001835  -0.008062
#
#             Balance
# Income     0.463656
# Limit      0.861697
# Rating     0.863625
# Cards      0.086456
# Age        0.001835
# Education -0.008062
# Balance    1.000000

# %%
import seaborn as sns

# Creiamo la heatmap con parametri personalizzati
plt.figure(figsize=(10, 8))
sns.heatmap(
    corr_matrix,
    cmap="magma_r",
    annot=True,
    fmt=".2f",
    linewidths=5,
    linecolor="white",
    vmin=-1,
    vmax=1,
    cbar_kws={"shrink": 0.8, "orientation": "vertical"},  # Personalizza la barra dei colori
    square=True
)

plt.title("Heatmap con maschera e personalizzazioni")
plt.show()

# %%
pippo['Age'].describe()
# Out:
# count    400.000000
# mean      55.667500
# std       17.249807
# min       23.000000
# 25%       41.750000
# 50%       56.000000
# 75%       70.000000
# max       98.000000
# Name: Age, dtype: float64

# %%
age_list = []

for i in pippo['Age']:
    if i > pippo['Age'].mean():
        age_list.append('Old')
    else:
        age_list.append('Young')

pippo['Synth_Age'] = age_list
pippo
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0     14.891   3606     283      2   34         11    Male      No     Yes
# 1    106.025   6645     483      3   82         15  Female     Yes     Yes
# 2    104.593   7075     514      4   71         11    Male      No      No
# 3    148.924   9504     681      3   36         11  Female      No      No
# 4     55.882   4897     357      2   68         16    Male      No     Yes
# ..       ...    ...     ...    ...  ...        ...     ...     ...     ...
# 395   12.096   4100     307      3   32         13    Male      No     Yes
# 396   13.364   3838     296      5   65         17    Male      No      No
# 397   57.872   4171     321      5   67         12  Female      No     Yes
# 398   37.728   2525     192      1   44         13    Male      No     Yes
# 399   18.701   5524     415      5   64          7  Female      No      No
#
#             Ethnicity  Balance Synth_Age
# ...

# %%
pippo['Synth_Age_Aggressive'] = ['Old' if i > pippo['Age'].mean() else 'Young' for i in pippo['Age']]
pippo[['Synth_Age','Synth_Age_Aggressive']]
# Out:
#     Synth_Age Synth_Age_Aggressive
# 0       Young                Young
# 1         Old                  Old
# 2         Old                  Old
# 3       Young                Young
# 4         Old                  Old
# ..        ...                  ...
# 395     Young                Young
# 396       Old                  Old
# 397       Old                  Old
# 398     Young                Young
# 399       Old                  Old
#
# [400 rows x 2 columns]

# %%
argomenti_webinar = ['LLMs', 'agents', 're-Act', 'Tools']
sigla_args_webinar = [i[0].upper() for i in argomenti_webinar]
print(*sigla_args_webinar)
# Out:
# L A R T

# %%
sigla_args_webinar = [i[0].upper() for i in argomenti_webinar if i != 'LLMs']
print(*sigla_args_webinar)
# Out:
# A R T

# %%
sigla_args_webinar = [i[0].upper() if i != 'LLMs' else 'This is F' for i in argomenti_webinar]
print(*sigla_args_webinar)
# Out:
# This is F A R T

# %%
pippo['Synth_Age_Extra_Aggressive'] = pippo['Age'].map(lambda x: 'Old' if x > pippo['Age'].mean() else 'Young')
pippo[['Age','Synth_Age','Synth_Age_Aggressive', 'Synth_Age_Extra_Aggressive']]
# Out:
#      Age Synth_Age Synth_Age_Aggressive Synth_Age_Extra_Aggressive
# 0     34     Young                Young                      Young
# 1     82       Old                  Old                        Old
# 2     71       Old                  Old                        Old
# 3     36     Young                Young                      Young
# 4     68       Old                  Old                        Old
# ..   ...       ...                  ...                        ...
# 395   32     Young                Young                      Young
# 396   65       Old                  Old                        Old
# 397   67       Old                  Old                        Old
# 398   44     Young                Young                      Young
# 399   64       Old                  Old                        Old
#
# [400 rows x 4 columns]

# %%
def do_something_strange(x):
    return x*3 - 1000

# %%
pippo['Strange_col'] = pippo['Age'].map(lambda x: do_something_strange(x) if x > 50 else x)
pippo[['Age','Strange_col']]
# Out:
#      Age  Strange_col
# 0     34           34
# 1     82         -754
# 2     71         -787
# 3     36           36
# 4     68         -796
# ..   ...          ...
# 395   32           32
# 396   65         -805
# 397   67         -799
# 398   44           44
# 399   64         -808
#
# [400 rows x 2 columns]

# %%
pippo['Age'].apply(do_something_strange)
# Out:
# 0     -898
# 1     -754
# 2     -787
# 3     -892
# 4     -796
#       ...
# 395   -904
# 396   -805
# 397   -799
# 398   -868
# 399   -808
# Name: Age, Length: 400, dtype: int64

# %%
pippo.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   14.891   3606     283      2   34         11    Male      No     Yes
# 1  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2  104.593   7075     514      4   71         11    Male      No      No
# 3  148.924   9504     681      3   36         11  Female      No      No
# 4   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance Synth_Age Synth_Age_Aggressive  \
# 0  Caucasian      333     Young                Young
# 1      Asian      903       Old                  Old
# 2      Asian      580       Old                  Old
# 3      Asian      964     Young                Young
# 4  Caucasian      331       Old                  Old
#
#   Synth_Age_Extra_Aggressive  Strange_col
# 0                      Young           34
# 1                        Old         -754
# 2                        Old         -787
# ...

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(x='Student', y='Balance', data=pippo, palette='muted')

plt.xticks(rotation=45)
plt.xlabel('Student')
plt.ylabel('Balance')
plt.title('Violin plot: Student vs Balance')
plt.show()
# Out:
# C:\Users\dilau\AppData\Local\Temp\ipykernel_16960\2975213594.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Student', y='Balance', data=pippo, palette='muted')

# %%
pippo[pippo['Student'] == 'No']['Balance'].hist()
# Out:
# <Axes: >

# %%
pippo[pippo['Student'] == 'Yes']['Balance'].hist()
# Out:
# <Axes: >

# %%
# Selezioniamo i valori di balance per i soli NON STUDENTI
balance_non_student = pippo[pippo['Student'] == 'No']['Balance']

# Selezioniamo i valori di balance per i soli STUDENTI
balance_student = pippo[pippo['Student'] == 'Yes']['Balance']

# Troviamo massimo e minimo della distribuzione
max_val, min_val = pippo.Balance.max(), pippo.Balance.min()

# Stampa valore minino e massion di balance
print(f"Min value: {min_val}")
print(f"Max value: {max_val}")
# Out:
# Min value: 0
# Max value: 1999

# %%
# Scegliamo esattamente la dimensione e posizione dei bin 
bins_edges = np.linspace(min_val, max_val, 11)
print(bins_edges)
# Out:
# [   0.   199.9  399.8  599.7  799.6  999.5 1199.4 1399.3 1599.2 1799.1
#  1999. ]

# %%
# Creiamo due subplot
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

fig.suptitle('Grafico doppio')

sns.histplot(balance_non_student, ax=axes[0], kde=True, color='dodgerblue', bins=bins_edges)
axes[0].set_title('Non Student')
axes[0].set_xlabel('Balance')
axes[0].set_ylabel('Count')

sns.histplot(balance_student, ax=axes[1], kde=True, color='darkred', bins=bins_edges)
axes[1].set_title('Student')
axes[1].set_xlabel('Balance')

# Allineare le scale dell'asse Y
max_y = max(axes[0].get_ylim()[1], axes[1].get_ylim()[1])
axes[0].set_ylim(0, max_y)
axes[1].set_ylim(0, max_y)

plt.tight_layout() # standard per migliorare il grafico
plt.show() # standard per mostrare il grafico

# %%
# Creiamo due subplot
fig, axes = plt.subplots(1, 2, figsize=(10, 7))

fig.suptitle('Grafico doppio')

sns.histplot(balance_non_student, ax=axes[0], kde=True, color='dodgerblue', bins=bins_edges)
axes[0].set_title('Non Student')
axes[0].set_xlabel('Balance')
axes[0].set_ylabel('Count')

sns.histplot(balance_student, ax=axes[1], kde=True, color='darkred', bins=bins_edges)
axes[1].set_title('Student')
axes[1].set_xlabel('Balance')

# Allineare le scale dell'asse Y
max_y = max(axes[0].get_ylim()[1], axes[1].get_ylim()[1])
axes[0].set_ylim(0, max_y)
axes[1].set_ylim(0, max_y)

plt.tight_layout() # standard per migliorare il grafico
plt.show() # standard per mostrare il grafico

# %%
# Creiamo due subplot
fig, axes = plt.subplots(2, 1, figsize=(10, 7))

fig.suptitle('Grafico doppio')

sns.histplot(balance_non_student, ax=axes[0], kde=True, color='dodgerblue', bins=bins_edges)
axes[0].set_title('Non Student')
axes[0].set_xlabel('Balance')
axes[0].set_ylabel('Count')

sns.histplot(balance_student, ax=axes[1], kde=True, color='darkred', bins=bins_edges)
axes[1].set_title('Student')
axes[1].set_xlabel('Balance')

# Allineare le scale dell'asse Y
# max_y = max(axes[0].get_ylim()[1], axes[1].get_ylim()[1])
# axes[0].set_ylim(0, max_y)
# axes[1].set_ylim(0, max_y)

plt.tight_layout() # standard per migliorare il grafico
plt.show() # standard per mostrare il grafico

# %%
plt.figure(figsize=(10, 5)) # Creiamo un nuovo grafico

# Per i NON STUDENTI
sns.histplot(balance_non_student, # Istogramma per i non studenti
         bins=bins_edges, # Bins personalizzati
         color='dodgerblue', # Scelgo un colore figo
         alpha=0.5, # Trasparenza
         kde=True, # Aggiungo la KDE cioè la curva di densità
         label='Non Student') # Questo è per la legenda

# Per gli STUDENTI
sns.histplot(balance_student, # Istogramma per gli studenti
        bins=bins_edges, # Bins personalizzati
        color='darkred', # Scelgo un colore figo
        kde=True, # Aggiungo la KDE cioè la curva di densità
        alpha=0.5, # Trasparenza
        label='Student') # Questo è per la legenda

plt.title('Distribuzione di Balance per Studenti e Non Studenti') # Titolo del grafico
plt.xlabel('Balance') # Etichetta asse X
plt.ylabel('Frequenza') # Etichetta asse Y
plt.legend() # Mostra la legenda
plt.grid() # Mostra la griglia

plt.tight_layout() # Migliora il layout
plt.show() # Mostra il grafico

# %%
plt.figure(figsize=(10, 5)) # Creiamo un nuovo grafico

# Per i NON STUDENTI
sns.histplot(balance_non_student, # Istogramma per i non studenti
         bins=bins_edges, # Bins personalizzati
         stat='density',
         color='dodgerblue', # Scelgo un colore figo
         alpha=0.5, # Trasparenza
         kde=True, # Aggiungo la KDE cioè la curva di densità
         label='Non Student') # Questo è per la legenda

# Per gli STUDENTI
sns.histplot(balance_student, # Istogramma per gli studenti
        bins=bins_edges, # Bins personalizzati
        stat='density',
        color='darkred', # Scelgo un colore figo
        kde=True, # Aggiungo la KDE cioè la curva di densità
        alpha=0.5, # Trasparenza
        label='Student') # Questo è per la legenda

plt.title('Distribuzione di Balance per Studenti e Non Studenti') # Titolo del grafico
plt.xlabel('Balance') # Etichetta asse X
plt.ylabel('Frequenza') # Etichetta asse Y
plt.legend() # Mostra la legenda
plt.grid(axis='x') # Mostra la griglia

plt.tight_layout() # Migliora il layout
plt.show() # Mostra il grafico

# %%
is_student = pippo['Student'] == 'Yes'
is_married = pippo['Married'] == 'Yes'
pippo_balance = pippo['Balance']
yy = pippo_balance[is_student & is_married]
yn = pippo_balance[is_student & ~is_married]
ny = pippo_balance[~is_student & is_married]
nn = pippo_balance[~is_student & ~is_married]

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 7))
fig.suptitle('Grafico quadruplo')
sns.histplot(yy, ax=axes[0,0], kde=True, stat='density', color='dodgerblue', bins=bins_edges)
axes[0,0].set_title('Married Student')
axes[0,0].set_xlabel('Balance')
axes[0,0].set_ylabel('Count')

sns.histplot(yn, ax=axes[0,1], kde=True, stat='density', color='darkred', bins=bins_edges)
axes[0,1].set_title('Not Married Student')
axes[0,1].set_xlabel('Balance')
axes[0,1].set_ylabel('Count')
sns.histplot(ny, ax=axes[1,0], kde=True, stat='density', color='dodgerblue', bins=bins_edges)
axes[1,0].set_title('Married not Student')
axes[1,0].set_xlabel('Balance')
axes[1,0].set_ylabel('Count')
sns.histplot(nn, ax=axes[1,1], kde=True, stat='density', color='darkred', bins=bins_edges)
axes[1,1].set_title('Not Married not Student')
axes[1,1].set_xlabel('Balance')
axes[1,1].set_ylabel('Count')
plt.tight_layout() # standard per migliorare il grafico
plt.show() # standard per mostrare il grafico
